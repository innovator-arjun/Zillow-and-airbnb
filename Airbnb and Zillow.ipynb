# %%
import pandas as pd

# %%
zillowdf=pd.read_csv('bedroom.csv')

# %%
zillowdf.head()
# Out:
#    RegionID             RegionName         City State  \
# 0    274772       Northeast Dallas       Dallas    TX
# 1    192689               Paradise    Las Vegas    NV
# 2    118208      South Los Angeles  Los Angeles    CA
# 3    192796          Spring Valley    Las Vegas    NV
# 4    268496  Southeast Los Angeles  Los Angeles    CA
#
#                             Metro          CountyName  SizeRank   1996-04  \
# 0     Dallas-Fort Worth-Arlington       Dallas County         1   80700.0
# 1    Las Vegas-Henderson-Paradise        Clark County         2   86300.0
# 2  Los Angeles-Long Beach-Anaheim  Los Angeles County         3  118500.0
# 3    Las Vegas-Henderson-Paradise        Clark County         4   82800.0
# 4  Los Angeles-Long Beach-Anaheim  Los Angeles County         5  105300.0
#
#     1996-05   1996-06   ...     2016-09  2016-10  2016-11  2016-12  2017-01  \
# 0   80900.0   81200.0   ...      168800   173200   177400   180500   182800
# 1   86400.0   86400.0   ...      113400   113900   114800   116000   117000
# 2  118500.0  118400.0   ...      349300   353700   358800   364700   369300
# 3   82700.0   82500.0   ...      110300   111500   112800   114200   115300
# 4  105200.0  105000.0   ...      294500   298500   302800   306100   308000
#
#    2017-02  2017-03  2017-04  2017-05  2017-06
# 0   186100   191100   196700   201900   205500
# 1   117800   118600   120200   122100   123700
# 2   372500   375700   379400   383000   386200
# 3   116600   118400   120700   122900   124800
# 4   309000   309400   311000   313800   316400
#
# [5 rows x 262 columns]

# %%
zillowdf.shape
# Out:
# (3861, 262)

# %%
#Have to add the graphs......and EDA

# %%
state= zillowdf['State']=='NY'

# %%
zillowdf=zillowdf[state]

# %%
zillowdf.shape
# Out:
# (69, 262)

# %%
zillowdf.head()
# Out:
#      RegionID     RegionName        City State                        Metro  \
# 146     22021       Fairport    Perinton    NY                    Rochester
# 195     27225  Spring Valley      Ramapo    NY  New York-Newark-Jersey City
# 221     39971       New City  Clarkstown    NY  New York-Newark-Jersey City
# 267     21885       Holbrook       Islip    NY  New York-Newark-Jersey City
# 325     26061         Nanuet  Clarkstown    NY  New York-Newark-Jersey City
#
#           CountyName  SizeRank   1996-04   1996-05   1996-06   ...     \
# 146    Monroe County       147   99200.0   98900.0   98600.0   ...
# 195  Rockland County       196  114100.0  113600.0  113100.0   ...
# 221  Rockland County       222  140100.0  140000.0  139800.0   ...
# 267   Suffolk County       268  117400.0  117000.0  116600.0   ...
# 325  Rockland County       326  161500.0  161300.0  161200.0   ...
#
#      2016-09  2016-10  2016-11  2016-12  2017-01  2017-02  2017-03  2017-04  \
# 146   173600   173200   172000   170200   167800   164900   162600   160500
# 195   269500   272000   274600   276600   276800   277000   282000   291300
# 221   262400   259900   257600   256100   256500   257900   259600   260900
# 267   269000   263700   261600   263400   263200   261600   260500   260000
# 325   309900   308900   307900   307500   309700   311600   311400   309900
#
#      2017-05  2017-06
# 146   158800   156800
# 195   302300   313200
# 221   262000   261200
# 267   260500   261900
# 325   310100   311200
#
# [5 rows x 262 columns]

# %%
zillowdf=zillowdf.rename(columns={'RegionID':'zipcode'})

# %%
col = zillowdf.loc[: , "1996-04":"2017-06"]

# %%
zillowdf['consolidated_price'] = col.mean(axis=1)
zillowdf['consolidated_price']=zillowdf['consolidated_price'].astype(int)
zillowdf.head()
# Out:
#      zipcode     RegionName        City State                        Metro  \
# 146    22021       Fairport    Perinton    NY                    Rochester
# 195    27225  Spring Valley      Ramapo    NY  New York-Newark-Jersey City
# 221    39971       New City  Clarkstown    NY  New York-Newark-Jersey City
# 267    21885       Holbrook       Islip    NY  New York-Newark-Jersey City
# 325    26061         Nanuet  Clarkstown    NY  New York-Newark-Jersey City
#
#           CountyName  SizeRank   1996-04   1996-05   1996-06  \
# 146    Monroe County       147   99200.0   98900.0   98600.0
# 195  Rockland County       196  114100.0  113600.0  113100.0
# 221  Rockland County       222  140100.0  140000.0  139800.0
# 267   Suffolk County       268  117400.0  117000.0  116600.0
# 325  Rockland County       326  161500.0  161300.0  161200.0
#
#             ...          2016-10  2016-11  2016-12  2017-01  2017-02  2017-03  \
# 146         ...           173200   172000   170200   167800   164900   162600
# 195         ...           272000   274600   276600   276800   277000   282000
# 221         ...           259900   257600   256100   256500   257900   259600
# 267         ...           263700   261600   263400   263200   261600   260500
# 325         ...           308900   307900   307500   309700   311600   311400
#
#      2017-04  2017-05  2017-06  consolidated_price
# 146   160500   158800   156800              125940
# 195   291300   302300   313200              208629
# 221   260900   262000   261200              248795
# 267   260000   260500   261900              228046
# 325   309900   310100   311200              292260
#
# [5 rows x 263 columns]

# %%
zillowdf=zillowdf[['zipcode','RegionName','City','State','SizeRank','consolidated_price']]

# %%
zillowdf.head()
# Out:
#      zipcode     RegionName        City State  SizeRank  consolidated_price
# 146    22021       Fairport    Perinton    NY       147              125940
# 195    27225  Spring Valley      Ramapo    NY       196              208629
# 221    39971       New City  Clarkstown    NY       222              248795
# 267    21885       Holbrook       Islip    NY       268              228046
# 325    26061         Nanuet  Clarkstown    NY       326              292260

# %%
zillowdf.to_csv(r'refined_zillow.csv')

# %%
aribnbdf=pd.read_csv('listings.csv.gz')
# Out:
# C:\Users\avaithil\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (43,61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
aribnbdf.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2454  https://www.airbnb.com/rooms/2454  20190201155637   2019-02-01
# 1  2539  https://www.airbnb.com/rooms/2539  20190201155637   2019-02-02
# 2  2595  https://www.airbnb.com/rooms/2595  20190201155637   2019-02-02
# 3  3330  https://www.airbnb.com/rooms/3330  20190201155637   2019-02-02
# 4  3647  https://www.airbnb.com/rooms/3647  20190201155637   2019-02-02
#
#                                   name  \
# 0                           superCondo
# 1   Clean & quiet apt home by the park
# 2                Skylit Midtown Castle
# 3   ++ Brooklyn Penthouse Guestroom ++
# 4  THE VILLAGE OF HARLEM....NEW YORK !
#
#                                              summary  \
# 0  Great light, exposed brick and 10 feet high ce...
# 1           Renovated apt home in elevator building.
# 2  Find your romantic getaway to this beautiful, ...
# 3  This is a spacious, clean, furnished master be...
# 4                                                NaN
#
#                                                space  \
# 0  A fully renovated, West Elm furnished Condo, w...
# 1  Spacious, renovated, and clean apt home, one b...
# 2  - Spacious (500+ft²), immaculate and nicely fu...
# 3  Room Features: - clean, hardwood floors - 2 la...
# 4  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
#
#                                          description experiences_offered  \
# 0  Great light, exposed brick and 10 feet high ce...                none
# 1  Renovated apt home in elevator building. Spaci...                none
# 2  Find your romantic getaway to this beautiful, ...                none
# 3  This is a spacious, clean, furnished master be...                none
# 4  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
#
#                                neighborhood_overview        ...          \
# 0  Turtle bay neighborhood in the heart of midtow...        ...
# 1    Close to Prospect Park and Historic Ditmas Park        ...
# 2  Centrally located in the heart of Manhattan ju...        ...
# 3  Location is GREAT!! Right off the L train in t...        ...
# 4                                                NaN        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     flexible
# 1                f                        f                     moderate
# 2                f                        f  strict_14_with_grace_period
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             t                                t
# 3                             f                                f
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               8
# 2                               2
# 3                               3
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            5
# 2                                            0
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.00
# 1                                            3               0.23
# 2                                            1               0.38
# 3                                            0               0.35
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
airbnbdf=aribnbdf[['id','zipcode','bedrooms','price','weekly_price','monthly_price','cleaning_fee','number_of_reviews','review_scores_rating']]

# %%
airbnbdf.head()
# Out:
#      id zipcode  bedrooms    price weekly_price monthly_price cleaning_fee  \
# 0  2454   10022       0.0  $137.00          NaN           NaN          NaN
# 1  2539   11218       1.0  $149.00      $299.00       $999.00       $25.00
# 2  2595   10018       0.0  $225.00    $1,995.00           NaN      $100.00
# 3  3330   11206       1.0   $70.00      $650.00     $1,900.00      $125.00
# 4  3647   10027       1.0  $150.00          NaN           NaN       $75.00
#
#    number_of_reviews  review_scores_rating
# 0                  1                   NaN
# 1                  9                  98.0
# 2                 43                  95.0
# 3                 39                  97.0
# 4                  0                   NaN

# %%
bedroom= airbnbdf['bedrooms']==2.0

# %%
airbnbdf=airbnbdf[bedroom]

# %%
airbnbdf.sample(20)
# Out:
#              id zipcode  bedrooms      price weekly_price monthly_price  \
# 2631    1171581   10036       2.0  $1,000.00          NaN           NaN
# 33698  22602605   11238       2.0     $95.00          NaN           NaN
# 9485    6660117   10009       2.0    $120.00          NaN     $3,600.00
# 6303    4198391   10009       2.0    $160.00    $1,200.00     $3,500.00
# 24904  17876530   10469       2.0    $105.00          NaN           NaN
# 49197  31520813   11233       2.0     $90.00          NaN           NaN
# 34453  23131155   11429       2.0    $120.00          NaN           NaN
# 17123  12405814   10455       2.0     $85.00          NaN           NaN
# 29685  20883200   10012       2.0    $350.00          NaN           NaN
# 30487  21280201   11207       2.0     $85.00          NaN           NaN
# 15765  11138910   11238       2.0    $109.00          NaN           NaN
# 46430  30399969   11222       2.0    $167.00          NaN           NaN
# 14336   9879796   10065       2.0    $249.00          NaN           NaN
# 33697  22601249   11101       2.0     $95.00          NaN           NaN
# 17271  12566413   11249       2.0    $325.00          NaN           NaN
# 43705  29338819   11354       2.0    $188.00          NaN           NaN
# 38135  25840272   10011       2.0    $299.00          NaN           NaN
# 33723  22627376   11222       2.0     $45.00          NaN           NaN
# 25553  18408236   11238       2.0    $188.00          NaN           NaN
# 6734    4482158   11215       2.0    $160.00          NaN           NaN
#
#       cleaning_fee  number_of_reviews  review_scores_rating
# 2631           NaN                  0                   NaN
# 33698       $40.00                  4                  90.0
# 9485       $150.00                  0                   NaN
# 6303        $60.00                  0                   NaN
# 24904      $100.00                 70                  94.0
# 49197          NaN                  0                   NaN
# 34453       $10.00                 48                  94.0
# 17123       $80.00                  4                  95.0
# 29685      $100.00                 54                  88.0
# 30487       $40.00                  3                  90.0
# 15765       $50.00                  3                 100.0
# 46430          NaN                  0                   NaN
# 14336      $100.00                  0                   NaN
# 33697      $100.00                 40                  95.0
# 17271       $50.00                  6                 100.0
# 43705       $30.00                  4                 100.0
# 38135       $99.00                 50                  92.0
# 33723          NaN                  1                 100.0
# 25553       $50.00                 49                  91.0
# 6734        $80.00                  1                 100.0

# %%
airbnbdf.shape
# Out:
# (6939, 9)

# %%
airbnb_null=airbnbdf.isnull().sum()
airbnb_null[airbnb_null>0].sort_values(ascending=False)
# Out:
# monthly_price           6165
# weekly_price            6083
# review_scores_rating    1468
# cleaning_fee            1021
# zipcode                   92
# dtype: int64

# %%
import numpy as np

# %%
airbnbdf.head()
# Out:
#        id zipcode  bedrooms    price weekly_price monthly_price cleaning_fee  \
# 54  13050   11221       2.0  $115.00      $850.00           NaN       $85.00
# 59  14290   11206       2.0  $224.00          NaN           NaN      $128.00
# 68  15230   11221       2.0  $185.00          NaN     $3,200.00      $120.00
# 72  15396   10001       2.0  $375.00    $2,750.00     $7,500.00      $100.00
# 80  16458   11215       2.0  $225.00          NaN           NaN          NaN
#
#     number_of_reviews  review_scores_rating
# 54                 11                  94.0
# 59                 75                  94.0
# 68                  9                  88.0
# 72                  5                 100.0
# 80                  4                 100.0

# %%
airbnbdf['price'] = airbnbdf['price'].str.replace('$', '')

# %%
airbnbdf['weekly_price'] = airbnbdf['weekly_price'].str.replace('$', '')
airbnbdf['monthly_price'] = airbnbdf['monthly_price'].str.replace('$', '')
airbnbdf['cleaning_fee'] = airbnbdf['cleaning_fee'].str.replace('$', '')

# %%
airbnbdf.weekly_price.fillna(airbnbdf.price*airbnbdf.price, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: can't multiply sequence by non-int of type 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: can't multiply sequence by non-int of type 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-1a9fa03de6f5> in <module>
# ----> 1 airbnbdf.weekly_price.fillna(airbnbdf.price*airbnbdf.price, inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
data["Multiplied values"]= airbnbdf["weekly_price"].mul(other = airbnbdf.price, fill_value = 850)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-eb8f52d86e9c> in <module>
# ----> 1 data["Multiplied values"]= airbnbdf["weekly_price"].mul(other = airbnbdf.price, fill_value = 850)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in flex_wrapper(self, other, level, fill_value, axis)
#    1375             self._get_axis_number(axis)
#    1376         if isinstance(other, ABCSeries):
# -> 1377             return self._binop(other, op, level=level, fill_value=fill_value)
#    1378         elif isinstance(other, (np.ndarray, list, tuple)):
#    1379             if len(other) != len(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in _binop(self, other, func, level, fill_value)
#    2190
#    2191         with np.errstate(all='ignore'):
# -> 2192             result = func(this_vals, other_vals)
#    2193         name = ops.get_op_result_name(self, other)
#    2194         result = self._constructor(result, index=new_index, name=name)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
airbnbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6939 entries, 54 to 50226
# Data columns (total 10 columns):
# id                      6939 non-null int64
# zipcode                 6847 non-null object
# bedrooms                6939 non-null float64
# price                   6939 non-null object
# weekly_price            856 non-null object
# monthly_price           774 non-null object
# cleaning_fee            5918 non-null object
# number_of_reviews       6939 non-null int64
# review_scores_rating    5471 non-null float64
# Multiplied values       6939 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 596.3+ KB

# %%
airbnbdf['price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-05594736b17f> in <module>
# ----> 1 airbnbdf['price'].astype(int)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src\util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '115.00'

# %% [markdown]
# 1. Have to fill NA in weekly, monthly cleaning using per day price column
# 2. merge zillow and airbnb using zipcode
# 3.Using Occupancy percentage find the revenue(working on the formula)
# 4. EDA for revenue using pin code.
