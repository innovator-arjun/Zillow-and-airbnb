# %%
import pandas as pd

# %%
zillowdf=pd.read_csv('Zip_Zhvi_2bedroom.csv')

# %%
zillowdf.head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06   ...     2016-09  2016-10  2016-11  \
# 0       NaN       NaN       NaN   ...     1374400  1364100  1366300
# 1  167700.0  166400.0  166700.0   ...      368600   370200   372300
# 2       NaN       NaN       NaN   ...     1993500  1980700  1960900
# 3  195800.0  193500.0  192600.0   ...      398900   401200   403200
# 4   59100.0   60500.0   60900.0   ...       82400    82300    82400
#
#      2016-12  2017-01  2017-02  2017-03  2017-04  2017-05  2017-06
# ...

# %%
zillowdf.shape
# Out:
# (8946, 262)

# %%
#Have to add the graphs......and EDA

# %%
city= zillowdf['City']=='New York'

# %%
zillowdf=zillowdf[city]

# %%
zillowdf.shape
# Out:
# (25, 262)

# %%
zillowdf.head()
# Out:
#     RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0      61639       10025  New York    NY  New York   New York         1
# 2      61637       10023  New York    NY  New York   New York         3
# 13     61703       10128  New York    NY  New York   New York        14
# 14     61625       10011  New York    NY  New York   New York        15
# 20     61617       10003  New York    NY  New York   New York        21
#
#     1996-04  1996-05  1996-06   ...     2016-09  2016-10  2016-11    2016-12  \
# 0       NaN      NaN      NaN   ...     1374400  1364100  1366300  1354800.0
# 2       NaN      NaN      NaN   ...     1993500  1980700  1960900  1951300.0
# 13      NaN      NaN      NaN   ...     1526000  1523700  1527200  1541600.0
# 14      NaN      NaN      NaN   ...     2354000  2355500  2352200  2332100.0
# 20      NaN      NaN      NaN   ...     1932800  1930400  1937500  1935100.0
#
#     2017-01  2017-02  2017-03  2017-04  2017-05  2017-06
# ...

# %%
zillowdf=zillowdf.rename(columns={'RegionName':'zipcode','2017-06':'LatestPrice'})

# %%
#col = zillowdf.loc[: , "1996-04":"2017-06"]
#zillowdf['cost'] = col.mean(axis=1)
#zillowdf['cost']=zillowdf['cost'].astype(int)
#zillowdf.head()

# %%
zillowdf.head()
# Out:
#     RegionID  zipcode      City State     Metro CountyName  SizeRank  1996-04  \
# 0      61639    10025  New York    NY  New York   New York         1      NaN
# 2      61637    10023  New York    NY  New York   New York         3      NaN
# 13     61703    10128  New York    NY  New York   New York        14      NaN
# 14     61625    10011  New York    NY  New York   New York        15      NaN
# 20     61617    10003  New York    NY  New York   New York        21      NaN
#
#     1996-05  1996-06     ...       2016-09  2016-10  2016-11    2016-12  \
# 0       NaN      NaN     ...       1374400  1364100  1366300  1354800.0
# 2       NaN      NaN     ...       1993500  1980700  1960900  1951300.0
# 13      NaN      NaN     ...       1526000  1523700  1527200  1541600.0
# 14      NaN      NaN     ...       2354000  2355500  2352200  2332100.0
# 20      NaN      NaN     ...       1932800  1930400  1937500  1935100.0
#
#     2017-01  2017-02  2017-03  2017-04  2017-05  LatestPrice
# ...

# %%
zillowdf=zillowdf[['zipcode','City','State','SizeRank','LatestPrice']]

# %%
zillowdf.head()
# Out:
#     zipcode      City State  SizeRank  LatestPrice
# 0     10025  New York    NY         1      1431000
# 2     10023  New York    NY         3      2142300
# 13    10128  New York    NY        14      1787100
# 14    10011  New York    NY        15      2480400
# 20    10003  New York    NY        21      2147000

# %%
#Visualizing The Data

# %%
highest_price=zillowdf.sort_values(by='LatestPrice',ascending=False)[:10]
lowest_price=zillowdf.sort_values(by='LatestPrice',ascending=False)[-10:]

# %%
highest_price
# Out:
#       zipcode      City State  SizeRank  LatestPrice
# 1743    10013  New York    NY      1744      3316500
# 378     10014  New York    NY       379      2491600
# 14      10011  New York    NY        15      2480400
# 20      10003  New York    NY        21      2147000
# 2       10023  New York    NY         3      2142300
# 108     10028  New York    NY       109      2083900
# 893     10022  New York    NY       894      2031600
# 189     10021  New York    NY       190      1815600
# 13      10128  New York    NY        14      1787100
# 579     10036  New York    NY       580      1712900

# %%
lowest_price
# Out:
#       zipcode      City State  SizeRank  LatestPrice
# 51      11234  New York    NY        52       476900
# 2086    10305  New York    NY      2087       425100
# 4148    10308  New York    NY      4149       409500
# 3681    10309  New York    NY      3682       390500
# 621     11434  New York    NY       622       382300
# 67      10314  New York    NY        68       357300
# 763     10312  New York    NY       764       355000
# 667     10306  New York    NY       668       352900
# 1957    10304  New York    NY      1958       328300
# 4646    10303  New York    NY      4647       327700

# %%
plt.figure(figsize=(12,9))

sns.barplot(zillowdf['zipcode'],zillowdf['LatestPrice'].sort_values(ascending=False),palette="gist_ncar",
                 linewidth = 1,edgecolor="k"*len(highest_price))

plt.title("Highest Price by ZipCode",color='b')
plt.show()

# %%
plt.figure(figsize=(12,9))

sns.barplot(lowest_price['zipcode'],lowest_price['LatestPrice'],palette="gist_ncar",
                 linewidth = 1,edgecolor="k"*len(highest_price))

plt.title("Highest Price by ZipCode",color='b')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,7))
index = np.arange(len(zillowdf.zipcode))
bar_width = 1
sorted_values = zillowdf.LatestPrice.sort_values(ascending=True)
plt.bar(index, sorted_values)
plt.xlabel('ZipCode', fontsize=15,)
plt.ylabel('Price', fontsize=15)
plt.xticks(index, zillowdf.zipcode, fontsize=15, rotation=90)
plt.yticks(fontsize=15)
plt.title(' Price by ZipCode',fontsize=25)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,7))
index = np.arange(len(zillowdf.zipcode))
bar_width = 1
sorted_values = zillowdf.LatestPrice.sort_values(ascending=False)[:10]
plt.bar(index[:10], sorted_values)
plt.xlabel('ZipCode', fontsize=15,)
plt.ylabel('Price', fontsize=15)
plt.xticks(index[:10], zillowdf.zipcode[:10], fontsize=15, rotation=90)
plt.yticks(fontsize=15)
plt.title('Top 10 Highest Price by ZipCode',fontsize=25)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,7))
index = np.arange(len(zillowdf.zipcode))
bar_width = 1
sorted_values = zillowdf.LatestPrice.sort_values(ascending=False)[-10:]
plt.bar(index[-10:], sorted_values)
plt.xlabel('ZipCode', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.xticks(index[-10:], zillowdf.zipcode[-10:], fontsize=15, rotation=90)
plt.yticks(fontsize=15)
plt.title('Top 10 Least Price by ZipCode',fontsize=25)
plt.show()

# %%
#zillowdf.to_csv(r'refined_zillow.csv')

# %%
aribnbdf=pd.read_csv('listings.csv.gz')
# Out:
# C:\Users\ARJUN_PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (43,61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
aribnbdf.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2454  https://www.airbnb.com/rooms/2454  20190201155637   2019-02-01
# 1  2539  https://www.airbnb.com/rooms/2539  20190201155637   2019-02-02
# 2  2595  https://www.airbnb.com/rooms/2595  20190201155637   2019-02-02
# 3  3330  https://www.airbnb.com/rooms/3330  20190201155637   2019-02-02
# 4  3647  https://www.airbnb.com/rooms/3647  20190201155637   2019-02-02
#
#                                   name  \
# 0                           superCondo
# 1   Clean & quiet apt home by the park
# 2                Skylit Midtown Castle
# 3   ++ Brooklyn Penthouse Guestroom ++
# 4  THE VILLAGE OF HARLEM....NEW YORK !
#
#                                              summary  \
# 0  Great light, exposed brick and 10 feet high ce...
# 1           Renovated apt home in elevator building.
# 2  Find your romantic getaway to this beautiful, ...
# 3  This is a spacious, clean, furnished master be...
# ...

# %%
airbnbdf=aribnbdf[['zipcode','bedrooms','price','weekly_price','monthly_price','cleaning_fee']]

# %%
airbnbdf.head()
# Out:
#   zipcode  bedrooms    price weekly_price monthly_price cleaning_fee
# 0   10022       0.0  $137.00          NaN           NaN          NaN
# 1   11218       1.0  $149.00      $299.00       $999.00       $25.00
# 2   10018       0.0  $225.00    $1,995.00           NaN      $100.00
# 3   11206       1.0   $70.00      $650.00     $1,900.00      $125.00
# 4   10027       1.0  $150.00          NaN           NaN       $75.00

# %%
bedroom= airbnbdf['bedrooms']==2.0

# %%
airbnbdf=airbnbdf[bedroom]

# %%
airbnbdf.sample(20)
# Out:
#       zipcode  bedrooms    price weekly_price monthly_price cleaning_fee
# 10121   11205       2.0  $205.00    $1,274.00     $4,920.00      $100.00
# 24673   11215       2.0   $90.00          NaN           NaN      $100.00
# 41333   10025       2.0   $99.00          NaN           NaN       $30.00
# 4504    11213       2.0  $125.00      $950.00     $2,700.00       $95.00
# 43991   11230       2.0  $185.00          NaN           NaN          NaN
# 10996   10014       2.0  $350.00    $2,200.00           NaN      $100.00
# 47506   10019       2.0  $225.00          NaN           NaN       $80.00
# 43612   10128       2.0  $215.00          NaN           NaN          NaN
# 32442   11211       2.0  $230.00          NaN           NaN          NaN
# 47222   10012       2.0  $228.00          NaN           NaN       $60.00
# 10949   11216       2.0  $150.00      $700.00     $2,500.00      $175.00
# 20040   11218       2.0  $130.00          NaN           NaN      $100.00
# ...

# %%
airbnbdf.shape
# Out:
# (6939, 6)

# %%
result = zillowdf.merge(airbnbdf, left_on=['zipcode'],
              right_on=['zipcode'],how='inner')

# %%
result_null=result.isnull().sum()
result_null[result_null>0].sort_values(ascending=False)
# Out:
# monthly_price    6165
# weekly_price     6083
# cleaning_fee     1021
# zipcode            92
# dtype: int64

# %%
import numpy as np

# %%
airbnbdf.head()
# Out:
#    zipcode  bedrooms    price weekly_price monthly_price cleaning_fee
# 54   11221       2.0  $115.00      $850.00           NaN       $85.00
# 59   11206       2.0  $224.00          NaN           NaN      $128.00
# 68   11221       2.0  $185.00          NaN     $3,200.00      $120.00
# 72   10001       2.0  $375.00    $2,750.00     $7,500.00      $100.00
# 80   11215       2.0  $225.00          NaN           NaN          NaN

# %%
airbnbdf['price'] = airbnbdf['price'].str.replace('$', '')
airbnbdf['price'] = airbnbdf['price'].str.replace(',', '')
airbnbdf['weekly_price'] = airbnbdf['weekly_price'].str.replace('$', '')
airbnbdf['weekly_price'] = airbnbdf['weekly_price'].str.replace(',', '')
airbnbdf['monthly_price'] = airbnbdf['monthly_price'].str.replace('$', '')
airbnbdf['monthly_price'] = airbnbdf['monthly_price'].str.replace(',', '')
airbnbdf['cleaning_fee'] = airbnbdf['cleaning_fee'].str.replace('$', '')
airbnbdf['cleaning_fee'] = airbnbdf['cleaning_fee'].str.replace(',', '')

# %%
airbnbdf[['price','weekly_price','monthly_price','cleaning_fee']]=airbnbdf[['price','weekly_price','monthly_price','cleaning_fee']].astype(float)

# %%
airbnbdf.weekly_price.fillna(airbnbdf.price*7, inplace=True)

# %%
airbnbdf.monthly_price.fillna(airbnbdf.price*30, inplace=True)

# %%
airbnbdf['cleaning_fee'].fillna((airbnbdf['cleaning_fee'].mean()), inplace=True)

# %%
airbnbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6939 entries, 54 to 50226
# Data columns (total 6 columns):
# zipcode          6847 non-null object
# bedrooms         6939 non-null float64
# price            6939 non-null float64
# weekly_price     6939 non-null float64
# monthly_price    6939 non-null float64
# cleaning_fee     6939 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 379.5+ KB

# %%
airbnbdf.head()
# Out:
#    zipcode  bedrooms  price  weekly_price  monthly_price  cleaning_fee
# 54   11221       2.0  115.0         850.0         3450.0       85.0000
# 59   11206       2.0  224.0        1568.0         6720.0      128.0000
# 68   11221       2.0  185.0        1295.0         3200.0      120.0000
# 72   10001       2.0  375.0        2750.0         7500.0      100.0000
# 80   11215       2.0  225.0        1575.0         6750.0       95.2805

# %%
airbnb_null=airbnbdf.isnull().sum()
airbnb_null[airbnb_null>0].sort_values(ascending=False)
# Out:
# zipcode    92
# dtype: int64

# %%
occupancy=0.75
airbnbdf['revenue_daily']=((airbnbdf.price*occupancy)+(airbnbdf.cleaning_fee*occupancy))

# %%
airbnbdf['revenue_weekly']=((airbnbdf.weekly_price*occupancy)+(airbnbdf.cleaning_fee*occupancy*7))

# %%
airbnbdf['revenue_monthly']=((airbnbdf.monthly_price*occupancy)+(airbnbdf.cleaning_fee*occupancy*30))

# %%
airbnbdf['revenue_yearly']=((airbnbdf.monthly_price*occupancy*12)+(airbnbdf.cleaning_fee*occupancy*365))

# %%
airbnbdf[['revenue_daily','revenue_weekly','revenue_monthly','revenue_yearly']]=airbnbdf[['revenue_daily','revenue_weekly','revenue_monthly','revenue_yearly']].astype(int)

# %%
airbnbdf.head()
# Out:
#    zipcode  bedrooms  price  weekly_price  monthly_price  cleaning_fee  \
# 54   11221       2.0  115.0         850.0         3450.0       85.0000
# 59   11206       2.0  224.0        1568.0         6720.0      128.0000
# 68   11221       2.0  185.0        1295.0         3200.0      120.0000
# 72   10001       2.0  375.0        2750.0         7500.0      100.0000
# 80   11215       2.0  225.0        1575.0         6750.0       95.2805
#
#     revenue_daily  revenue_weekly  revenue_monthly  revenue_yearly
# 54            150            1083             4500           54318
# 59            264            1848             7920           95520
# 68            228            1601             5100           61650
# 72            356            2587             7875           94875
# 80            240            1681             7206           86833

# %%
#airbnbdf.to_csv(r'airbnb_refined.csv')

# %%
result.head()
# Out:
#   zipcode      City State  SizeRank  LatestPrice  bedrooms  price  \
# 0   10025  New York    NY         1      1431000       2.0   99.0
# 1   10025  New York    NY         1      1431000       2.0  200.0
# 2   10025  New York    NY         1      1431000       2.0  300.0
# 3   10025  New York    NY         1      1431000       2.0  250.0
# 4   10025  New York    NY         1      1431000       2.0  239.0
#
#    weekly_price  monthly_price  cleaning_fee  revenue_daily  revenue_weekly  \
# 0         693.0         2970.0       30.0000             96             677
# 1        1400.0         6000.0      200.0000            300            2100
# 2        2100.0         9000.0      200.0000            375            2625
# 3        1750.0         7500.0       70.0000            240            1680
# 4        1673.0         7170.0       95.2805            250            1754
#
#    revenue_monthly  revenue_yearly
# 0             2902           34942
# 1             9000          108750
# ...

# %%
result.shape
# Out:
# (273, 14)

# %%
highest_daily=result.sort_values(by='revenue_daily',ascending=False)[:10]
lowest_daily=result.sort_values(by='revenue_daily',ascending=False)[-10:]

# %%
lowest_daily
# Out:
#     zipcode      City State  SizeRank  LatestPrice  bedrooms  price  \
# 212   11217  New York    NY      1555      1302300       2.0   98.0
# 249   11231  New York    NY      1817      1202900       2.0   78.0
# 0     10025  New York    NY         1      1431000       2.0   99.0
# 176   11434  New York    NY       622       382300       2.0   65.0
# 179   11434  New York    NY       622       382300       2.0   99.0
# 254   11231  New York    NY      1817      1202900       2.0   87.0
# 265   10303  New York    NY      4647       327700       2.0   71.0
# 178   11434  New York    NY       622       382300       2.0   83.0
# 264   10305  New York    NY      2087       425100       2.0   86.0
# 184   10306  New York    NY       668       352900       2.0   65.0
#
#      weekly_price  monthly_price  cleaning_fee  revenue_daily  revenue_weekly  \
# 212         686.0         2940.0          40.0            103             724
# ...

# %%
plt.figure(figsize=(13,7))
highest_daily['zipcode']=highest_daily['zipcode'].astype(str)
plt.scatter("zipcode","revenue_daily",data=highest_daily,c=highest_daily['revenue_daily'],s=500,alpha=.7,
            linewidth=2,edgecolor="k",)

plt.xticks(highest_daily['zipcode'].unique())
plt.xlabel('ZipCode')
plt.ylabel('Price')

plt.title('Total revenue-Daily by ZipCode')
# Out:
# Text(0.5,1,'Total revenue-Daily by ZipCode')

# %%
plt.figure(figsize=(13,7))
lowest_daily['zipcode']=lowest_daily['zipcode'].astype(str)
plt.scatter("zipcode","revenue_daily",data=lowest_daily,c=lowest_daily['revenue_daily'],s=500,alpha=.7,
            linewidth=2,edgecolor="k",)

plt.xticks(lowest_daily['zipcode'].unique())
plt.xlabel('ZipCode')
plt.ylabel('Price')

plt.title('Lowest revenue daily by ZipCode')
# Out:
# Text(0.5,1,'Lowest revenue daily by ZipCode')

# %% [markdown]
# 1. Have to fill NA in weekly, monthly cleaning using per day price column
# 2. merge zillow and airbnb using zipcode
# 3.Using Occupancy percentage find the revenue(working on the formula)
# 4. EDA for revenue using pin code.
